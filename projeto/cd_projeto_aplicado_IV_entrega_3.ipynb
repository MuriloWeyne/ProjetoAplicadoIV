# %% [markdown]
# <a href="https://colab.research.google.com/github/scalabrinig/cdProjetoAplicadoIV/blob/master/projeto/cd_projeto_aplicado_IV_entrega_3.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
#   <img src="https://raw.githubusercontent.com/scalabrinig/cdProjetoAplicadoIV/d093146488f56dfcf0ef286bcee8efe0e71b9c76/figuras/mackenzie_logo.jpg" width="25%" align="right"/>
#
# # **PROJETO APLICADO IV - Ciência de Dados EaD - 2026/01**
#
#
# # **Entrega 3**
#
# ---

# %% [markdown]
# # **Título do Projeto**: Modelagem e Previsão de Séries Temporais do Comércio Varejista no Estado de São Paulo
#
# ---

# %%
#@title **Identificação do Grupo e Opção do Projeto**

#@markdown Integrantes do Grupo, nome completo em ordem alfabética (*informe: \<nome\>, \<matrícula\>*)
Aluno1 = 'Murilo Prado Weyne, 10428607' #@param {type:"string"}

# %% [markdown]
# # **Introdução**
#
# O comércio varejista brasileiro tem passado por várias transformações nas últimas décadas, impulsionadas principalmente pela expansão do comércio eletrônico e pela digitalização dos canais de venda. Nesse cenário, o estado de São Paulo consolida-se como o principal polo varejista do país, concentrando grande parte do volume de transações comerciais realizadas tanto em lojas físicas quanto em plataformas digitais, bem como a maior parcela do comércio eletrônico nacional. Conforme apontam Bagatini e Laimer (2019), o desempenho do varejo online no Brasil apresentou crescimento consistente ao longo do período de 2003 a 2018, refletindo mudanças estruturais nos hábitos de consumo da população e na infraestrutura tecnológica disponível.
#
# Diante deste contexto, a análise de séries temporais apresenta-se como ferramenta estatística essencial para a compreensão do comportamento do volume de vendas ao longo do tempo. Séries temporais permitem identificar tendências de longo prazo, padrões sazonais e eventuais rupturas estruturais nos dados, agindo como meios para a elaboração de diagnósticos e previsões fundamentadas. A Pesquisa Mensal de Comércio (PMC), conduzida pelo IBGE, disponibiliza dados mensais sobre o volume de vendas do comércio varejista por unidade da federação, constituindo uma fonte robusta para a aplicação de técnicas de modelagem temporal.
#
# O monitoramento sistemático do consumo varejista dialoga diretamente com os Objetivos de Desenvolvimento Sustentável (ODS) estabelecidos pela Agenda 2030 das Nações Unidas. A análise da infraestrutura digital que sustenta o crescimento do varejo eletrônico relaciona-se ao ODS 9, que trata de Indústria, Inovação e Infraestrutura, enquanto a compreensão dos padrões de consumo e de suas trajetórias temporais contribui para os objetivos do ODS 12, relativo a Consumo e Produção Responsáveis (IPEA, 2024).
#
# Nesse sentido, este projeto propõe-se a analisar a evolução do volume de vendas do comércio varejista no estado de São Paulo, utilizando os dados da tabela 8880 da PMC/IBGE com granularidade mensal a partir do ano 2000. Os dados correspondem ao índice de volume de vendas no comércio varejista do estado de São Paulo, com base de referência em 2022 (média do ano = 100), disponíveis de janeiro de 2000 a dezembro de 2025, totalizando 312 observações mensais, acessíveis em: https://sidra.ibge.gov.br/tabela/8880.
#
# ## Objetivos
#
# ### Objetivo Geral
#
# Analisar a evolução temporal do volume de vendas do comércio varejista no estado de São Paulo e desenvolver modelos preditivos de aprendizado de máquina para subsidiar decisões estratégicas de gestores e formuladores de políticas públicas, em alinhamento com os ODS 9 e 12 da Agenda 2030.
#
# ### Objetivos Específicos
#
# 1. Identificar e caracterizar os componentes da série temporal do volume de vendas do comércio varejista paulista — tendência, sazonalidade e ciclos —, a partir dos dados mensais da PMC/IBGE no período de 2000 a 2025.
# 2. Desenvolver e avaliar modelos preditivos voltados à previsão do volume de vendas do varejo no estado de São Paulo.
# 3. Comparar o desempenho preditivo dos modelos propostos e indicar o de melhor resultado como ferramenta de suporte à tomada de decisão.
#
# ## Justificativa
#
# A análise do volume de vendas do comércio varejista no estado de São Paulo, estruturada sob a perspectiva de séries temporais, justifica-se pela centralidade que o varejo ocupa na economia brasileira e pelo papel preponderante que São Paulo desempenha nesse segmento. Compreender a trajetória temporal dessas vendas permite não apenas identificar padrões de crescimento e sazonalidade, mas também detectar os efeitos de choques econômicos, mudanças regulatórias e transformações tecnológicas sobre o comportamento do consumo.
#
# Do ponto de vista do alinhamento com a Agenda 2030, o projeto contribui para o monitoramento de padrões de consumo ao longo do tempo, dialogando com o ODS 12, enquanto o emprego de técnicas de ciência de dados e modelagem estatística fortalece a infraestrutura de dados e a cultura de inovação analítica, em consonância com os objetivos do ODS 9.

# %% [markdown]
# # **Referencial Teórico**
#
# Uma série temporal é definida como um conjunto de observações coletadas sequencialmente ao longo do tempo em intervalos regulares (SILVA; PERES; BOSCARIOLI, 2016). A análise de séries temporais tem por objetivo identificar padrões e extrair características significativas dos dados, possibilitando a realização de previsões e o suporte à tomada de decisão em diferentes domínios, como finanças, saúde e comércio.
#
# Os principais componentes de uma série temporal são: (i) **tendência**, que representa a direção de longo prazo dos dados; (ii) **sazonalidade**, que corresponde a padrões de variação regular que se repetem em intervalos fixos de tempo; (iii) **ciclos**, variações repetitivas cujo período não é fixo; e (iv) **ruído** (erro aleatório), variações irregulares e inexplicáveis nos dados (SILVA; PERES; BOSCARIOLI, 2016). Uma série é classificada como **estacionária** quando sua média e variância permanecem constantes ao longo do tempo.
#
# ## Levantamento das Técnicas de Modelagem
#
# A partir da revisão da literatura, identificam-se duas principais classes de técnicas como as mais adequadas para séries temporais com tendência e sazonalidade marcadas, como a série de volume de vendas do varejo paulista:
#
# ### Modelos Autorregressivos Integrados de Médias Móveis Sazonais (SARIMA)
#
# O modelo **ARIMA** (*Autoregressive Integrated Moving Average*) combina componentes autorregressivos (AR), de integração (I) e de médias móveis (MA), sendo parametrizado por (p, d, q). A extensão sazonal **SARIMA** (*Seasonal ARIMA*), parametrizada por (p, d, q)(P, D, Q, s), incorpora explicitamente a componente sazonal ao modelo, sendo especialmente adequada para séries com padrões de sazonalidade regulares de período s (s=12 para dados mensais), como o índice de volume de vendas do varejo (BOX et al., 2015).
#
# **Vantagens:** Interpretabilidade dos parâmetros; capacidade de modelar dependência temporal e sazonalidade; base estatística consolidada; menor custo computacional.
#
# **Limitações:** Pressupõe linearidade; sensibilidade à escolha dos hiperparâmetros (p, d, q, P, D, Q); requer estacionarização prévia da série.
#
# **Justificativa para uso:** A série apresenta tendência de longo prazo e sazonalidade anual bem definida (pico em dezembro/novembro), características que o SARIMA captura diretamente. Serve como modelo de referência (*baseline*) pela sua interpretabilidade e robustez estatística.
#
# ### Redes Neurais Recorrentes com Memória de Longo Prazo (LSTM)
#
# As **Redes Neurais Recorrentes** (*Recurrent Neural Networks* — RNN) processam sequências por meio de uma arquitetura com retroalimentação, conferindo ao modelo capacidade de "memória" sobre observações anteriores (IBM, s.d.). A variante **LSTM** (*Long Short-Term Memory*), proposta por Hochreiter e Schmidhuber (1997), supera as RNNs simples ao mitigar o problema do desaparecimento do gradiente por meio de portas de controle (entrada, esquecimento e saída), tornando-a mais eficaz na captura de dependências de longo prazo.
#
# **Vantagens:** Capacidade de modelar não linearidades e dependências de longo prazo; não requer pressuposto de estacionaridade; flexibilidade arquitetural.
#
# **Limitações:** Exigem maior volume de dados para treinamento; maior custo computacional; menor interpretabilidade em comparação aos modelos estatísticos.
#
# No contexto do varejo brasileiro, Bagatini e Laimer (2019) analisaram o desempenho do varejo online no Brasil entre 2003 e 2018, documentando crescimento estrutural consistente no período. O presente projeto adota o modelo SARIMA como abordagem principal, dada a adequação da técnica às características da série (tendência e sazonalidade regulares) e sua interpretabilidade estatística.

# %% [markdown]
# # **Diagrama de Solução**
#
# O pipeline proposto para a análise e previsão do volume de vendas do comércio varejista de São Paulo compreende cinco etapas sequenciais:
#
# ```
# Coleta dos dados → Pré-processamento → EDA & Visualização → Modelagem → Avaliação e Validação
# ```
#
# **1. Coleta dos dados**
# Os dados são obtidos via API pública do IBGE (Serviço de Dados IBGE), referentes à tabela 8880 da PMC. A coleta é automatizada via requisições HTTP, recuperando o índice de volume de vendas no comércio varejista do estado de São Paulo no período de janeiro de 2000 a dezembro de 2025 (312 observações mensais).
#
# **2. Pré-processamento**
# Esta etapa envolve: conversão das datas para o formato `datetime` com frequência mensal (`MS`); verificação e tratamento de eventuais valores faltantes; conversão dos valores do índice para tipo numérico; e organização da série com o índice temporal como referência.
#
# **3. Análise Exploratória dos Dados (EDA) e Visualização**
# Produção de: (i) gráfico de linha da série histórica completa com destaque para eventos econômicos relevantes; (ii) boxplot por mês do ano para visualização do padrão sazonal; (iii) mapa de calor mensal ao longo dos anos; e (iv) média e desvio padrão móveis de 12 meses.
#
# **4. Modelagem**
# O modelo preditivo implementado é o **SARIMA** (Seasonal Autoregressive Integrated Moving Average), modelo estatístico clássico com extensão sazonal, selecionado por sua adequação às características da série (tendência e sazonalidade regulares) e interpretabilidade dos parâmetros. Por razões de simplificação, a implementação de modelos de aprendizado profundo (LSTM) não foi incluída nesta entrega.
#
# **5. Avaliação e Validação**
# Divisão temporal: treino (jan/2000–dez/2022, 276 obs.) e teste (jan/2023–dez/2025, 36 obs.).
#
# | Métrica | Descrição |
# |---|---|
# | MAE | *Mean Absolute Error* — erro absoluto médio |
# | RMSE | *Root Mean Squared Error* — raiz do erro quadrático médio |
# | MAPE | *Mean Absolute Percentage Error* — erro percentual absoluto médio |

# %% [markdown]
# # **EDA e Pré-processamento dos dados**

# %%
# Instalação de pacotes adicionais
# !pip install pmdarima -q

import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import matplotlib.dates as mdates
import seaborn as sns
import requests
import warnings
warnings.filterwarnings('ignore')

# Modelos estatísticos
from statsmodels.tsa.statespace.sarimax import SARIMAX
import pmdarima as pm

# Métricas de avaliação
from sklearn.metrics import mean_absolute_error, mean_squared_error

# Visualização
plt.style.use('seaborn-v0_8-whitegrid')
plt.rcParams['figure.figsize'] = (14, 5)
plt.rcParams['figure.dpi'] = 100
sns.set_palette('deep')

print(f'NumPy: {np.__version__}')
print(f'Pandas: {pd.__version__}')
print('Bibliotecas carregadas com sucesso!')

# %%
# Coleta de dados do IBGE

print('Coletando dados da PMC/IBGE — Tabela 8880...')

url_dados = (
    'https://servicodados.ibge.gov.br/api/v3/agregados/8880'
    '/periodos/all/variaveis/7169'
    '?localidades=N3[35]&classificacao=11046[56734]'
)
resp = requests.get(url_dados, timeout=60)
resp.raise_for_status()
resultado_api = resp.json()

print(f'Variável: {resultado_api[0]["variavel"]}')
print(f'Unidade : {resultado_api[0]["unidade"]}')
print(f'Categoria: {list(resultado_api[0]["resultados"][0]["classificacoes"][0]["categoria"].values())[0]}')
print(f'Localidade: {resultado_api[0]["resultados"][0]["series"][0]["localidade"]["nome"]}')
# Out:
# Coletando dados da PMC/IBGE — Tabela 8880...
# Variável: PMC - Número-índice (2022=100)
# Unidade : Número-índice
# Categoria: Índice de volume de vendas no comércio varejista
# Localidade: São Paulo

# %%
# Construindo a série temporal
serie_dict = resultado_api[0]['resultados'][0]['series'][0]['serie']

df_raw = pd.DataFrame(
    list(serie_dict.items()),
    columns=['periodo', 'valor']
)
df_raw['data'] = pd.to_datetime(df_raw['periodo'], format='%Y%m')
df_raw['valor'] = pd.to_numeric(df_raw['valor'], errors='coerce')
df_raw = df_raw.sort_values('data').set_index('data')

# Série temporal com frequência mensal explícita
ts = df_raw['valor'].asfreq('MS')

print(f'Período: {ts.index[0].strftime("%B de %Y")} a {ts.index[-1].strftime("%B de %Y")}')
print(f'Total de observações: {len(ts)}')
print(f'Valores ausentes: {ts.isna().sum()}')
print(f'\nEstatísticas descritivas:')
display(ts.describe().round(4).rename('Índice de Volume').to_frame())
# Out:
# Período: January de 2000 a February de 2026
# Total de observações: 314
# Valores ausentes: 0
#
# Estatísticas descritivas:
#        Índice de Volume
# count          314.0000
# mean            80.3452
# std             23.0650
# min             41.2697
# 25%             55.9630
# 50%             88.5808
# 75%             97.3149
# max            129.9010

# %%
# Verificando a qualidade dos dados
print(f'Tipo da série: {ts.dtype}')
print(f'Frequência: {ts.index.freq}')
print(f'Valores ausentes: {ts.isna().sum()}')
print(f'Valores negativos ou zero: {(ts <= 0).sum()}')

# Verificar continuidade temporal (sem lacunas)
periodos_esperados = pd.date_range(ts.index[0], ts.index[-1], freq='MS')
lacunas = periodos_esperados.difference(ts.index)
print(f'Lacunas na série: {len(lacunas)}')

if ts.isna().sum() > 0:
    print('Aplicando interpolação linear para valores ausentes...')
    ts = ts.interpolate(method='linear')

print('\nSérie pronta para análise.')
# Out:
# === Verificação de Qualidade ===
# Tipo da série: float64
# Frequência: <MonthBegin>
# Valores ausentes: 0
# Valores negativos ou zero: 0
# Lacunas na série: 0
#
# Série pronta para análise.

# %%
# ── VISUALIZAÇÃO 1: SÉRIE TEMPORAL COMPLETA ──────────────────────────────────
fig, ax = plt.subplots(figsize=(16, 5))
ax.plot(ts.index, ts.values, color='steelblue', linewidth=1.2, label='Índice de volume')

# Destacar eventos relevantes
eventos = {
    '2008-09': ('Crise financeira\nglobal', 'tomato'),
    '2015-01': ('Recessão\nbras. 2015-16', 'darkorange'),
    '2020-03': ('Pandemia\nCOVID-19', 'crimson'),
}
for data_str, (label, cor) in eventos.items():
    ax.axvline(pd.Timestamp(data_str), color=cor, linestyle='--', alpha=0.6, linewidth=1.5)
    ax.text(pd.Timestamp(data_str), ts.max() * 0.96, label,
            fontsize=8, color=cor, ha='center', va='top',
            bbox=dict(boxstyle='round,pad=0.2', fc='white', alpha=0.7))

ax.axhline(100, color='gray', linestyle=':', linewidth=1, label='Base = 100 (média 2022)')
ax.set_title('Índice de Volume de Vendas — Comércio Varejista, São Paulo (2000–2025)', fontsize=14)
ax.set_xlabel('Ano')
ax.set_ylabel('Índice (base: média 2022 = 100)')
ax.legend(loc='upper left')
ax.xaxis.set_major_locator(mdates.YearLocator(2))
ax.xaxis.set_major_formatter(mdates.DateFormatter('%Y'))
plt.xticks(rotation=45)
plt.tight_layout()
plt.show()
# Out:
# Observações visuais:
#   • Tendência de crescimento de longo prazo ao longo de todo o período.
#   • Pico sazonal recorrente em dezembro (período natalino).
#   • Quedas acentuadas em 2008-09 (crise financeira) e 2020 (pandemia).
#   • Recuperação rápida pós-pandemia, com novo patamar superior a 100 a partir de 2021.

# %%
# Boxplot Mensal
df_eda = ts.to_frame(name='valor')
df_eda['mes'] = df_eda.index.month
df_eda['ano'] = df_eda.index.year

meses_label = ['Jan','Fev','Mar','Abr','Mai','Jun','Jul','Ago','Set','Out','Nov','Dez']

fig, ax = plt.subplots(figsize=(14, 5))
df_eda.boxplot(column='valor', by='mes', ax=ax,
               boxprops=dict(color='steelblue'),
               medianprops=dict(color='tomato', linewidth=2),
               whiskerprops=dict(color='steelblue'),
               capprops=dict(color='steelblue'),
               flierprops=dict(marker='o', color='gray', alpha=0.5, markersize=4))
ax.set_xticklabels(meses_label)
ax.set_title('Distribuição do Índice de Volume por Mês', fontsize=13)
ax.set_xlabel('Mês')
ax.set_ylabel('Índice (base: média 2022 = 100)')
plt.suptitle('')
plt.tight_layout()
plt.show()

# Médias mensais
media_mensal = df_eda.groupby('mes')['valor'].mean().round(2)
media_mensal.index = meses_label
print('Média histórica por mês:')
display(media_mensal.to_frame().T)
# Out:
# Média histórica por mês:
#          Jan    Fev    Mar    Abr    Mai   Jun    Jul    Ago    Set    Out  \
# valor  76.98  71.99  77.95  75.65  79.38  76.5  78.74  79.76  77.23  81.12
#
#          Nov     Dez
# valor  84.08  105.21

# %%
# Heatmap
pivot = df_eda.pivot_table(values='valor', index='ano', columns='mes')
pivot.columns = meses_label

fig, ax = plt.subplots(figsize=(16, 10))
sns.heatmap(pivot, annot=False, fmt='.1f', cmap='YlOrRd',
            linewidths=0.4, linecolor='white',
            cbar_kws={'label': 'Índice de Volume'},
            ax=ax)
ax.set_title('Mapa de Calor — Índice de Volume de Vendas por Ano e Mês', fontsize=13)
ax.set_xlabel('Mês')
ax.set_ylabel('Ano')
plt.tight_layout()
plt.show()
# Out:
# O mapa de calor evidencia:
#   • Crescimento gradual do nível ao longo dos anos (de tons amarelos para laranja/vermelho).
#   • Picos consistentes em dezembro (último mês) em todos os anos.
#   • Queda abrupta visível em 2020 (primeira metade do ano — pandemia COVID-19).

# %%
# Visualização do desvio padrão e médias móveis
janela = 12
media_movel = ts.rolling(window=janela).mean()
std_movel = ts.rolling(window=janela).std()

fig, axes = plt.subplots(2, 1, figsize=(16, 8))

axes[0].plot(ts, color='steelblue', alpha=0.6, linewidth=1, label='Série original')
axes[0].plot(media_movel, color='darkorange', linewidth=2, label=f'Média móvel ({janela}m)')
axes[0].set_title('Média Móvel de 12 Meses', fontsize=12)
axes[0].set_ylabel('Índice')
axes[0].legend()

axes[1].plot(std_movel, color='seagreen', linewidth=1.5, label=f'Desvio padrão móvel ({janela}m)')
axes[1].set_title('Desvio Padrão Móvel de 12 Meses', fontsize=12)
axes[1].set_ylabel('Desvio padrão')
axes[1].legend()

for ax in axes:
    ax.xaxis.set_major_locator(mdates.YearLocator(2))
    ax.xaxis.set_major_formatter(mdates.DateFormatter('%Y'))
    plt.setp(ax.xaxis.get_majorticklabels(), rotation=45)

plt.tight_layout()
plt.show()
# Out:
# A média móvel crescente confirma tendência de alta de longo prazo.
# O desvio padrão móvel instável indica variância não constante (série não estacionária).

# %% [markdown]
# # **Modelo base**
#
# Com base nas evidências da EDA, confirmou-se que a série:
# - Apresenta **tendência crescente** de longo prazo, evidenciada pela média móvel de 12 meses
# - Possui **sazonalidade anual** bem definida com período s=12, visível no boxplot mensal e no mapa de calor
# - Requer diferenciação de primeira ordem (d=1) e sazonal (D=1) para estacionarização, conforme prática padrão para séries com essas características (BOX et al., 2015)
#
# > **Nota:** Embora o escopo original previsse a implementação de dois modelos (SARIMA e LSTM), optou-se, por razões de simplificação, por implementar apenas o modelo **SARIMA** nesta entrega. O SARIMA é o modelo de referência estatístico mais adequado para séries com tendência e sazonalidade regulares como esta, e sua interpretabilidade o torna suficiente para os objetivos analíticos propostos. A comparação com modelos de aprendizado profundo fica como trabalho futuro.

# %%
corte = '2022-12'
ts_train = ts[ts.index <= corte]
ts_test  = ts[ts.index >  corte]

print(f'Treino : {ts_train.index[0].strftime("%b/%Y")} a {ts_train.index[-1].strftime("%b/%Y")} — {len(ts_train)} observações')
print(f'Teste  : {ts_test.index[0].strftime("%b/%Y")} a {ts_test.index[-1].strftime("%b/%Y")} — {len(ts_test)} observações')

def avaliar_modelo(y_true, y_pred, nome):
    mae  = mean_absolute_error(y_true, y_pred)
    rmse = np.sqrt(mean_squared_error(y_true, y_pred))
    mape = np.mean(np.abs((np.array(y_true) - np.array(y_pred)) / np.array(y_true))) * 100
    print(f'\n--- {nome} ---')
    print(f'MAE  : {mae:.4f}')
    print(f'RMSE : {rmse:.4f}')
    print(f'MAPE : {mape:.4f}%')
    return {'Modelo': nome, 'MAE': round(mae, 4), 'RMSE': round(rmse, 4), 'MAPE (%)': round(mape, 4)}

# %% [markdown]
# ## Modelo SARIMA

# %%
# Sarima com seleção automática de parametros
print('Executando auto_arima (busca em grid com critério AIC)...')
print('Parâmetros fixos: d=1, D=1, s=12')
print('Espaço de busca: p,q ∈ [0,2], P,Q ∈ [0,2]\n')

auto_model = pm.auto_arima(
    ts_train,
    start_p=0, max_p=2,
    start_q=0, max_q=2,
    start_P=0, max_P=2,
    start_Q=0, max_Q=2,
    d=1, D=1, m=12,
    seasonal=True,
    information_criterion='aic',
    stepwise=True,
    suppress_warnings=True,
    error_action='ignore',
    trace=True
)

print(f'\nMelhor modelo encontrado: SARIMA{auto_model.order}x{auto_model.seasonal_order}')
print(f'AIC: {auto_model.aic():.2f}')
# Out:
# Executando auto_arima (busca em grid com critério AIC)...
# Parâmetros fixos: d=1, D=1, s=12
# Espaço de busca: p,q ∈ [0,2], P,Q ∈ [0,2]
#
# Performing stepwise search to minimize aic
#  ARIMA(0,1,0)(0,1,0)[12]             : AIC=1358.382, Time=0.02 sec
#  ARIMA(1,1,0)(1,1,0)[12]             : AIC=1295.313, Time=0.19 sec
#  ARIMA(0,1,1)(0,1,1)[12]             : AIC=1261.974, Time=0.20 sec
#  ARIMA(0,1,1)(0,1,0)[12]             : AIC=1327.076, Time=0.04 sec
#  ARIMA(0,1,1)(1,1,1)[12]             : AIC=1263.388, Time=0.33 sec
#  ARIMA(0,1,1)(0,1,2)[12]             : AIC=1263.329, Time=0.50 sec
#  ARIMA(0,1,1)(1,1,0)[12]             : AIC=1285.434, Time=0.15 sec
#  ARIMA(0,1,1)(1,1,2)[12]             : AIC=1265.290, Time=1.10 sec
#  ARIMA(0,1,0)(0,1,1)[12]             : AIC=1288.738, Time=0.17 sec
#  ARIMA(1,1,1)(0,1,1)[12]             : AIC=1254.049, Time=0.32 sec
#  ARIMA(1,1,1)(0,1,0)[12]             : AIC=1312.989, Time=0.08 sec
# ...

# %%
# Ajustando o modelo com a biblioteca statsmodels
order         = auto_model.order           # (p, d, q)
seasonal_order = auto_model.seasonal_order # (P, D, Q, s)

sarima_model = SARIMAX(
    ts_train,
    order=order,
    seasonal_order=seasonal_order,
    enforce_stationarity=False,
    enforce_invertibility=False
)
sarima_fit = sarima_model.fit(disp=False)

print(sarima_fit.summary())
# Out:
#                                       SARIMAX Results
# ...
# Dep. Variable:                                valor   No. Observations:                  276
# Model:             SARIMAX(2, 1, 2)x(0, 1, [1], 12)   Log Likelihood                -588.682
# Date:                              Sun, 26 Apr 2026   AIC                           1189.364
# Time:                                      15:51:44   BIC                           1210.444
# Sample:                                  01-01-2000   HQIC                          1197.850
#                                        - 12-01-2022
# Covariance Type:                                opg
# ...
#                  coef    std err          z      P>|z|      [0.025      0.975]
# ------------------------------------------------------------------------------
# ar.L1         -0.4782      0.146     -3.282      0.001      -0.764      -0.193
# ar.L2          0.2638      0.108      2.448      0.014       0.053       0.475
# ...

# %%
# Diagnóstico dos resíduos SARIMA
fig = sarima_fit.plot_diagnostics(figsize=(16, 10))
fig.suptitle(f'Diagnóstico dos Resíduos — SARIMA{order}x{seasonal_order}', fontsize=13)
plt.tight_layout()
plt.show()

# %%
# Previsão e Avaliação
n_test = len(ts_test)

sarima_pred_obj = sarima_fit.get_forecast(steps=n_test)
sarima_pred     = sarima_pred_obj.predicted_mean
sarima_ci       = sarima_pred_obj.conf_int(alpha=0.05)

res_sarima = avaliar_modelo(ts_test.values, sarima_pred.values, f'SARIMA{order}x{seasonal_order}')

# Tabela de resultados
import pandas as pd
df_resultados = pd.DataFrame([res_sarima]).set_index('Modelo')
print('\n=== Métricas de Desempenho ===')
display(df_resultados.round(4))

# Visualização
fig, ax = plt.subplots(figsize=(16, 5))
ax.plot(ts_train[-48:], color='steelblue', linewidth=1.2, label='Treino (últimos 4 anos)')
ax.plot(ts_test, color='seagreen', linewidth=2, label='Real (teste)')
ax.plot(sarima_pred, color='darkorange', linewidth=2, linestyle='--', label='SARIMA (previsão)')
ax.fill_between(sarima_ci.index,
                sarima_ci.iloc[:, 0],
                sarima_ci.iloc[:, 1],
                color='darkorange', alpha=0.15, label='IC 95%')
ax.axvline(ts_test.index[0], color='gray', linestyle=':', linewidth=1.5)
ax.set_title(f'SARIMA{order}x{seasonal_order} — Previsão vs. Real (jan/2023–dez/2025)', fontsize=13)
ax.set_xlabel('Período')
ax.set_ylabel('Índice de Volume')
ax.legend()
plt.tight_layout()
plt.show()

# %% [markdown]
# # **Referências**
#
# BAGATINI, Francine Zanin; LAIMER, Claudionor Guedes. O contexto do e-commerce no Brasil: análise do desempenho do varejo online no período de 2003 a 2018. In: CONGRESSO LATINO-AMERICANO DE VAREJO E CONSUMO, 2019, São Paulo. Anais... São Paulo: FGV, 2019. Disponível em: https://conferencias.fgv.br/clav/article/view/852. Acesso em: 1 mar. 2026.
#
# BOX, George E. P.; JENKINS, Gwilym M.; REINSEL, Gregory C.; LJUNG, Greta M. Time series analysis: forecasting and control. 5. ed. Hoboken: Wiley, 2015.
#
# HOCHREITER, Sepp; SCHMIDHUBER, Jürgen. Long short-term memory. Neural Computation, v. 9, n. 8, p. 1735-1780, nov. 1997.
#
# IBM. What is a recurrent neural network (RNN)?. Disponível em: https://www.ibm.com/topics/recurrent-neural-networks. Acesso em: 25 mar. 2026.
#
# INSTITUTO BRASILEIRO DE GEOGRAFIA E ESTATÍSTICA. Pesquisa Mensal de Comércio. Rio de Janeiro: IBGE, 2000-2025. Disponível em: https://sidra.ibge.gov.br/tabela/8880. Acesso em: 1 mar. 2026.
#
# INSTITUTO DE PESQUISA ECONÔMICA APLICADA. Agenda 2030: objetivos de desenvolvimento sustentável: avaliação do progresso das principais metas globais para o Brasil: ODS 12: consumo responsável – assegurar padrões de consumo e produção sustentável. Brasília: Ipea, 2024. 19 p. (Cadernos ODS, 12). DOI: http://dx.doi.org/10.38116/ri2024ODS12. Disponível em: https://repositorio.ipea.gov.br/handle/11058/14136. Acesso em: 1 mar. 2026.
#
# SILVA, Leandro Augusto da; PERES, Sarajane Marques; BOSCARIOLI, Clodis. Introdução à mineração de dados com aplicações em R. 1. ed. Rio de Janeiro: Elsevier, 2016.

# %%
#@title **Avaliação**
EDA_e_preprocessamento = 10 #@param {type:"slider", min:0, max:10, step:1}

Modelo_base = 10 #@param {type:"slider", min:0, max:10, step:1}

# %%
#@title **Nota Final**
nota = 0.50*EDA_e_preprocessamento + 0.50*Modelo_base

print(f'Nota final do trabalho {nota :.1f}')

import numpy as np
import pandas as pd

alunos = pd.DataFrame()

lista_nome = []

for i in range(1,6):
  exec("if Aluno" + str(i) + " !='None':  lista = Aluno" + str(i) + ".split(','); lista_nome.append(lista[0]);")

alunos['nome'] = lista_nome
alunos['nota'] = np.round(nota,1)
print()
display(alunos)
# Out:
# Nota final do trabalho 10.0
#                  nome  nota
# 0  Murilo Prado Weyne  10.0
